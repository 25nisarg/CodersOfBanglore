# %% [markdown]
# # Coders of Bangalore
# You ask Sam Altman for a 2.2 billion USD in funding and he makes fun of you in public
#
# He asks you where you live and finally after talking to you, gives you a challenging task
#
# Collect raw instagram data of all openai followers
#
# Answer these questions:
#
# - Who has maximum posts
# - who has maximum followers
# - Who follows maximum people
# - How many categories (Digital creators, Non profit foundation etc do we have) of how many people do we have?
#
# You have 24 hours
#
# You then ask for data - he laughs!

# %%
with open("finaldata.txt", encoding="utf-8") as f:
    data=f.read()

# %%
chunks=data.split("\n\n")
chunks=[c for c in  chunks if len(c)>5]

# %%
def parse_chunk(chunk):
        chunk=chunk.strip()
        sep_chunk= chunk.split("\n")
        username=sep_chunk[0]
        no_of_post=int(sep_chunk[1].split(" post")[0].replace(",",""))
        no_of_followers=float(sep_chunk[2].split(" follower")[0].replace(",","").replace("K","").replace("M",""))
        
        if("K" in sep_chunk[2]):
            no_of_followers=int(no_of_followers*1000)  
        elif("M" in sep_chunk[2]):
            no_of_followers=int(no_of_followers*1000)
        else:
            no_of_followers=int(no_of_followers)

        no_of_following=float(sep_chunk[3].split(" following")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[3]):
            no_of_following=int(no_of_following*1000)  
        elif("M" in sep_chunk[3]):
            no_of_following=int(no_of_following*1000)
        else:
            no_of_following=int(no_of_following)
            
        name=sep_chunk[4]
        if(len(sep_chunk)>5):
            type=sep_chunk[5]
            bio="\n".join(sep_chunk[6:])
        else:
            type="Unknown"
            bio=""
        return{"username":username,"no_of_post": no_of_post,"no_of_followers": no_of_followers,"no_of_following": no_of_following,
           "name":name,"type":type,"bio":bio}
# Out:
# {'username': 'blrcoder_girl', 'no_of_post': 150, 'no_of_followers': 6300, 'no_of_following': 120, 'name': 'Riya Codes', 'type': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunk=parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
# Out:
# [{'username': 'techie_koramangala', 'no_of_post': 420, 'no_of_followers': 9800, 'no_of_following': 310, 'name': 'Arjun M.', 'type': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_post': 150, 'no_of_followers': 6300, 'no_of_following': 120, 'name': 'Riya Codes', 'type': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_post': 980, 'no_of_followers': 22400, 'no_of_following': 95, 'name': 'Startup Stories HSR', 'type': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_post': 210, 'no_of_followers': 4500, 'no_of_following': 60, 'name': 'Naveen DevOps', 'type': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'}, {'username': 'koramangala_coffee_lover', 'no_of_post': 300, 'no_of_followers': 7900, 'no_of_following': 180, 'name': 'Sana B.', 'type': 'Cafe Explorer', 'bio': '☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter'}, {'username': 'ai_bangalore_news', 'no_of_post': 1340, 'no_of_followers': 38000, 'no_of_following': 200, 'name': 'AI Bangalore', 'type': 'Media', 'bio': '🤖 Daily AI news from India\n📢 Startup & research updates\naibanglore.ai/news'}, {'username': 'techfounder_india', 'no_of_post': 210, 'no_of_followers': 19000, 'no_of_following': 450, 'name': 'Dev Patel', 'type': 'Founder', 'bio': '⚡ Building SaaS in Fintech\n📍 Indiranagar\ndevpatel.io'}, {'username': 'coder_on_orr', 'no_of_post': 65, 'no_of_followers': 1900, 'no_of_following': 70, 'name': 'Sriram', 'type': 'Backend Developer', 'bio': '🐍 Python | FastAPI enthusiast\n🌧️ Surviving ORR traffic\ngithub.com/sriramworks'}, {'username': 'blrdatascience_daily', 'no_of_post': 540, 'no_of_followers': 15100, 'no_of_following': 150, 'name': 'Bangalore DS Daily', 'type': 'Media', 'bio': '📊 Data + AI + ML\n👩\u200d🏫 Tutorials | Job alerts\nblrdatascience.in'}, {'username': 'frontend_with_megha', 'no_of_post': 175, 'no_of_followers': 8200, 'no_of_following': 95, 'name': 'Megha Gupta', 'type': 'Frontend Dev', 'bio': '🎨 React | Next.js | UI Tips\n🌸 Bengaluru\nmeghacodes.dev'}, {'username': 'cubbonpark_runner', 'no_of_post': 95, 'no_of_followers': 1500, 'no_of_following': 40, 'name': 'Aman', 'type': 'Lifestyle', 'bio': '🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'}, {'username': 'indiranagar_food_maps', 'no_of_post': 600, 'no_of_followers': 12300, 'no_of_following': 155, 'name': 'Food Maps BLR', 'type': 'Food & Drink', 'bio': '🍜 Maps of best places around Indiranagar\n📍 Bangalore\nfoodmapsblr.com'}, {'username': 'python_blr_jobs', 'no_of_post': 1200, 'no_of_followers': 21000, 'no_of_following': 18, 'name': 'Python Jobs BLR', 'type': 'Community', 'bio': '💼 Python/ML/AI jobs daily\n📍 Bengaluru\npythonblr.jobs'}, {'username': 'sarjapur_coder', 'no_of_post': 143, 'no_of_followers': 3200, 'no_of_following': 52, 'name': 'Roshan', 'type': 'Full-stack Dev', 'bio': '🧑\u200d💻 MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev'}, {'username': 'open_source_blr', 'no_of_post': 300, 'no_of_followers': 9100, 'no_of_following': 78, 'name': 'BLR Open Source', 'type': 'Community', 'bio': '🌐 Meetups | Talks | OSS\ngithub.com/blropensource'}, {'username': 'techwalk_blr', 'no_of_post': 430, 'no_of_followers': 11000, 'no_of_following': 320, 'name': 'Tech Walk Bangalore', 'type': 'Media', 'bio': '🚶 Exploring tech parks & cafes\n📍 Ecoworld | Manyata | Bagmane\ntechwalkblr.com'}, {'username': 'itpl_daily', 'no_of_post': 590, 'no_of_followers': 14200, 'no_of_following': 210, 'name': 'ITPL Daily', 'type': 'Blog', 'bio': '🏢 Inside Whitefield Tech Life\n🚌 Bus stand stories included\nmedium.com/@itpldaily'}, {'username': 'react_native_blr', 'no_of_post': 220, 'no_of_followers': 4700, 'no_of_following': 6 ...

# %%
import json

# %%
s = json.dumps(all_chunks,indent=4)
print(s)
# Out:
# [
#     {
#         "username": "techie_koramangala",
#         "no_of_post": 420,
#         "no_of_followers": 9800,
#         "no_of_following": 310,
#         "name": "Arjun M.",
#         "type": "Software Engineer",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "username": "blrcoder_girl",
#         "no_of_post": 150,
#         "no_of_followers": 6300,
#         "no_of_following": 120,
#         "name": "Riya Codes",
#         "type": "Tech Creator",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_post": 980,
#         "no_of_followers": 22400,
#         "no_of_following": 95,
#         "name": "Startup Stories HSR",
#         "type": "Media",
#         "bio": "\ud83d\ude80 Interviews with Bangalore founders\n\ud83c\udf99\ufe0f Weekly startup breakdowns\nhsrstartupstories.com"
#     },
#     {
#         "username": "cloud_dev_blr",
#         "no_of_post": 210,
#         "no_of_followers": 4500,
#         "no_of_following": 60,
#         "name": "Naveen DevOps",
#         "type": "Engineer",
#         "bio": "\u2601\ufe0f AWS | Docker | K8s\n\ud83d\udccd Sarjapur\ngithub.com/naveencloud"
#     },
#     {
#         "username": "koramangala_coffee_lover",
#         "no_of_post": 300,
#         "no_of_followers": 7900,
#         "no_of_following": 180,
#         "name": "Sana B.",
#         "type": "Cafe Explorer",
#         "bio": "\u2615 Reviewing Bangalore\u2019s hidden coffee spots\n\ud83d\udccd Koramangala\nyoutube.com/@sanacafehunter"
#     },
#     {
#         "username": "ai_bangalore_news",
#         "no_of_post": 1340,
#         "no_of_followers": 38000,
#         "no_of_following": 200,
#         "name": "AI Bangalore",
#         "type": "Media",
#         "bio": "\ud83e\udd16 Daily AI news from India\n\ud83d\udce2 Startup & research updates\naibanglore.ai/news"
#     },
#     {
#         "username": "techfounder_india",
#         "no_of_post": 210,
#         "no_of_followers": 19000,
#         "no_of_following": 450,
#         "name": "Dev Patel",
#         "type": "Founder",
#         "bio": "\u26a1 Building SaaS in Fintech\n\ud83d\udccd Indiranagar\ndevpatel.io"
#     },
#     {
#         "username": "coder_on_orr",
#         "no_of_post": 65,
#         "no_of_followers": 1900,
#         "no_of_following": 70,
#         "name": "Sriram",
#         "type": "Backend Developer",
#         "bio": "\ud83d\udc0d Python | FastAPI enthusiast\n\ud83c\udf27\ufe0f Surviving ORR traffic\ngithub.com/sriramworks"
#     },
#     {
#         "username": "blrdatascience_daily",
#         "no_of_post": 540,
#         "no_of_followers": 15100,
#         "no_of_following": 150,
#         "name": "Bangalore DS Daily",
#         "type": "Media",
#         "bio": "\ud83d\udcca Data + AI + ML\n\ud83d\udc69\u200d\ud83c\udfeb Tutorials | Job alerts\nblrdatascience.in"
#     },
#     {
#         "username": "frontend_with_megha",
#         "no_of_post": 175,
#         "no_of_followers": 8200,
#         "no_of_following": 95,
#         "name": "Megha Gupta",
#         "type": "Frontend Dev",
#         "bio": "\ud83c\udfa8 React | Next.js | UI Tips\n\ud83c\udf38 Bengaluru\nmeghacodes.dev"
#     },
#     {
#         "username": "cubbonpark_runner",
#         "no_of_post": 95,
#         "no_of_followers": 1500,
#         "no_of_following": 40,
#         "name": "Aman",
#         "type": "Lifestyle",
#         "bio": "\ud83c\udfc3 Running after coding\n\ud83d\udccd Cubbon Park\nstrava.com/amanrunning"
#     },
#     {
#         "username": "indiranagar_food_maps",
#         "no_of_post": 600,
#         "no_of_followers": 12300,
#         "no_of_following": 155,
#         "name": "Food Maps BLR",
#         "type": "Food & Drink",
#         "bio": "\ud83c\udf5c Maps of best places around Indiranagar\n\ud83d\udccd Bangalore\nfoodmapsblr.com"
#     },
#     {
#         "username": "python_blr_jobs",
#         "no_of_post": 1200,
#         "no_of_followers": 21000,
#         "no_of_following": 18,
#         "name": "Python Jobs BLR",
#         "type": "Community",
#         "bio": "\ud83d\udcbc Python/ML/AI jobs daily\n\ud83d\udccd Bengaluru\npythonblr.jobs"
#     },
#     {
#         "username": "sarjapur_coder",
#         "no_of_post": 143,
#         "no_of_followers": 3200,
#         "no_of_following": 52,
#         "name": "Roshan",
#         "type": "Full-stack Dev",
#         "bio": "\ud83e\uddd1\u200d\ud83d\udcbb MERN | DevTools\nCurrently debugging from Sarjapur\nroshancodes.dev"
#     },
#     {
#         "username": "open_source_blr",
#         "no_of_post": 300,
#         "no_of_followers": 9100,
#         "no_of_following": 78,
#         "name": "BLR Open Source",
#         "type": "Community",
#         "bio": "\ud83c\udf10 Meetups | Talks | OSS\ngithub.com/blropensource"
#     },
#     {
#         "username": "techwalk_blr",
#         "no_of_post": 430,
#         "no_of_followers": 11000,
#         "no_of_following": 320,
#         "name": "Tech Walk Bangalore",
#         "type": "Media",
#         "bio": "\ud83d\udeb6 Exploring tech parks & cafes\n\ud83d\udccd Ecoworld | Manyata | Bagmane\ntechwalkblr.com"
#     },
#     {
#         "username": "itpl_daily",
#         "no_of_post": 590,
#         "no_of_followers": 14200,
#         "no_of_following": 210,
#         "name": "ITPL Daily",
#         "type": "Blog",
#         "bio": "\ud83c\udfe2 Inside Whitefield Tech Life\n\ud83d\ude8c Bus stand stories included\nmedium.com/@itpldaily"
#     },
#     {
#         "username": "react_native_blr",
#         "no_of_post": 220,
#         "no_of_followers": 4700,
#         "no_of_following": 60,
#         "name": "RN Bangalore",
#         "type": "Community",
#         "bio": "\ud83d\udcf1 React Native Tips | Meetups\nrnblr.dev"
#     },
#     {
#         "username": "founder_doodles",
#         "no_of_post": 80,
#         "no_of_followers": 2300,
#         "no_of_following": 20,
#         "name": "Kushal",
#         "type": "Artist + Coder",
#         "bio": "\u270f\ufe0f Startup doodles\n\ud83d\udcbb YC fanboy\nkushaldraws.com"
#     },
#     {
#         "username": "blrproductmanager",
#         "no_of_post": 160,
#         "no_of_followers": 6800,
#         "no_of_following": 110,
#         "name": "Sanya | PM",
#         "type": "Product Manager",
#         "bio": "\ud83d\udccd Koramangala\n\ud83d\udd0d Breaking down apps\nsanyapm.com"
#     },
#     {
#         "username": "machinelearning_blr",
#         "no_of_post": 490,
#         "no_of_followers": 17800,
#         "no_of_following": 140,
#         "name": "ML Bangalore",
#         "type": "Community",
#         "bio": "\ud83e\udd16 Workshops | Resources\nmlblr.in"
#     },
#     {
#         "username": "bengaluru_startup_recruiter",
#         "no_of_post": 135,
#         "no_of_followers": 5900,
#         "no_of_following": 300,
#         "name": "Ankita HR",
#         "type": "Recruiter",
#         "bio": "\ud83e\udd84 Hiring for early-stage startups\n\ud83d\udccd Indiranagar\nankitarecruits.in"
#     },
#     {
#         "username": "coffeeandcode_blr",
#         "no_of_post": 77,
#         "no_of_followers": 1400,
#         "no_of_following": 44,
#         "name": "Aditya",
#         "type": "Developer",
#         "bio": "\u2615 Coffee + VSCode = Happiness\n\ud83d\udccd HSR\ngithub.com/coffeeandcodeblr"
#     },
#     {
#         "username": "uiux_blr_design",
#         "no_of_post": 210,
#         "no_of_followers": 9500,
#         "no_of_following": 130,
#         "name": "UI/UX Bangalore",
#         "type": "Design",
#         "bio": "\ud83c\udfa8 Case studies, tips, mock UI\nuiuxblr.design"
#     },
#     {
#         "username": "whitefield_cafe_explorer",
#         "no_of_post": 480,
#         "no_of_followers": 7600,
#         "no_of_following": 250,
#         "name": "Radhika",
#         "type": "Cafe Nerd",
#         "bio": "\u2615 Whitefield cafes & reading corners\n\ud83d\udcd8 Book recs\ninstareadsblr.com"
#     },
#     {
#         "username": "jslover_bangalore",
#         "no_of_post": 120,
#         "no_of_followers": 3800,
#         "no_of_following": 32,
#         "name": "Jatin Codes",
#         "type": "Engineer",
#         "bio": "\u26a1 JavaScript everything\n\ud83d\udccd MG Road\ngithub.com/jatincodesjs"
#     },
#     {
#         "username": "blrautotechtalk",
#         "no_of_post": 310,
#         "no_of_followers": 8400,
#         "no_of_following": 260,
#         "name": "AutoTech BLR",
#         "type": "Media",
#         "bio": "\ud83d\ude97 EVs | Autonomous | Mobility\n\ud83d\udccd Bengaluru\nautotechblr.com"
#     },
#     {
#         "username": "deeptech_india",
#         "no_of_post": 900,
#         "no_of_followers": 24000,
#         "no_of_following": 290,
#         "name": "DeepTech India",
#         "type": "Media",
#         "bio": "\ud83d\udee0\ufe0f Indian AI + Robotics + Chips\ndeeptechindia.ai"
#     },
#     {
#         "username": "startupdating_blr",
#         "no_of_post": 140,
#         "no_of_followers": 5000,
#         "no_of_following": 40,
#         "name": "Startup Dating",
#         "type": "Blog",
#         "bio": "\ud83d\udc94 Founders + Investors = Drama\n\ud83d\udccd HSR\nmedium.com/startupdatingblr"
#     },
#     {
#         "username": "codingkannadiga",
#         "no_of_post": 190,
#         "no_of_followers": 7200,
#         "no_of_following": 150,
#         "name": "Praveen",
#         "type": "Tech Creator",
#         "bio": "\ud83d\udcbb Python + Kannada Tutorials\nyoutube.com/@codingkannadiga"
#     },
#     {
#         "username": "koramangala_hustlers",
#         "no_of_post": 800,
#         "no_of_followers": 18700,
#         "no_of_following": 300,
#         "name": "Koramangala Hustlers",
#         "type": "Lifestyle",
#         "bio": "\ud83d\udcbc Startups, events, coworks\nkorahustlers.com"
#     },
#     {
#         "username": "mlops_blr",
#         "no_of_post": 210,
#         "no_of_followers": 6400,
#         "no_of_following": 70,
#         "name": "MLOps Bangalore",
#         "type": "Community",
#         "bio": "\ud83d\udee0\ufe0f ML infra | Deployments\nmlopsblr.in"
#     },
#     {
#         "username": "producthunt_blr",
#         "no_of_post": 340,
#         "no_of_followers": 10500,
#         "no_of_following": 190,
#         "name": "Product Hunt BLR",
#         "type": "Media",
#         "bio": "\ud83d\ude80 New launches from Indian builders\nproducthuntblr.com"
#     },
#     {
#         "username": "ai_research_india",
#         "no_of_post": 170,
#         "no_of_followers": 8800,
#         "no_of_following": 60,
#         "name": "AI Research India",
#         "type": "Education",
#         "bio": "\ud83d\udcc4 Papers, datasets, repos\nairesearchindia.org"
#     },
#     {
#         "username": "fullstack_dev_anjali",
#         "no_of_post": 90,
#         "no_of_followers": 2100,
#         "no_of_following": 35,
#         "name": "Anjali",
#         "type": "Developer",
#         "bio": "\ud83c\udf08 Full-stack tutorials\n\ud83d\udccd BTM Layout\nanjalicodes.tech"
#     },
#     {
#         "username": "bangalorebikecoder",
#         "no_of_post": 60,
#         "no_of_followers": 1300,
#         "no_of_following": 30,
#         "name": "Vijay",
#         "type": "Coder",
#         "bio": "\ud83d\udeb4 Cycling to office, coding after\n\ud83d\udccd Bellandur\nstrava.com/vijayblr"
#     },
#     {
#         "username": "codewithchai_blr",
#         "no_of_post": 110,
#         "no_of_followers": 3400,
#         "no_of_following": 50,
#         "name": "Chai + Code",
#         "type": "Lifestyle",
#         "bio": "\u2615 Chai spots + dev stories\nchaiandcode.com"
#     },
#     {
#         "username": "indiranagar_startuplab",
#         "no_of_post": 220,
#         "no_of_followers": 12000,
#         "no_of_following": 160,
#         "name": "Startup Lab",
#         "type": "Community",
#         "bio": "\ud83e\uddea Experiments with early-stage founders\nindiranagarstartuplab.com"
#     },
#     {
#         "username": "pythonforkids_blr",
#         "no_of_post": 95,
#         "no_of_followers": 2700,
#         "no_of_following": 22,
#         "name": "Python Kids BLR",
#         "type": "Education",
#         "bio": "\ud83d\udc76 Coding classes for kids\npythonforkidsblr.in"
#     },
#     {
#         "username": "devrel_blr",
#         "no_of_post": 180,
#         "no_of_followers": 7900,
#         "no_of_following": 70,
#         "name": "DevRel Bangalore",
#         "type": "Community",
#         "bio": "\ud83c\udfa4 Talks | Dev advocacy | Tools\ndevrelblr.org"
#     },
#     {
#         "username": "techpark_memes",
#         "no_of_post": 350,
#         "no_of_followers": 16000,
#         "no_of_following": 250,
#         "name": "Tech Park Memes",
#         "type": "Comedy",
#         "bio": "\ud83d\ude02 Jokes from Ecospace, Manyata & more\nbit.ly/techparkmemes"
#     },
#     {
#         "username": "hsr_designstudio",
#         "no_of_post": 400,
#         "no_of_followers": 9400,
#         "no_of_following": 280,
#         "name": "HSR Design Studio",
#         "type": "Design",
#         "bio": "\ud83d\udd8c\ufe0f Freelance UI/UX\n\ud83d\udccd HSR\nhsrdesignstudio.in"
#     },
#     {
#         "username": "kaggler_blr",
#         "no_of_post": 130,
#         "no_of_followers": 4200,
#         "no_of_following": 40,
#         "name": "Kaggle Bangalore",
#         "type": "Data Science",
#         "bio": "\ud83d\udcca Competitions, kernels\nkagglerblr.com"
#     },
#     {
#         "username": "datascience_rider",
#         "no_of_post": 75,
#         "no_of_followers": 1600,
#         "no_of_following": 33,
#         "name": "Naman",
#         "type": "Data Scientist",
#         "bio": "\ud83c\udfcd\ufe0f Rides + ML\n\ud83d\udccd Indiranagar\nnamanml.dev"
#     },
#     {
#         "username": "bootcamp_blr",
#         "no_of_post": 310,
#         "no_of_followers": 8600,
#         "no_of_following": 80,
#         "name": "Bangalore Bootcamp",
#         "type": "Education",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Coding bootcamps & workshops\nbootcampblr.in"
#     },
#     {
#         "username": "buildinpublic_blr",
#         "no_of_post": 270,
#         "no_of_followers": 6200,
#         "no_of_following": 50,
#         "name": "Build in Public BLR",
#         "type": "Community",
#         "bio": "\ud83d\udcc8 Indie hackers & SaaS founders\nbuildinpublicblr.com"
#     },
#     {
#         "username": "intaglobal",
#         "no_of_post": 1946,
#         "no_of_followers": 6851,
#         "no_of_following": 262,
#         "name": "INTA",
#         "type": "Nonprofit organization",
#         "bio": "The association of \u2122 professionals.\ninta.campsite.bio"
#     },
#     {
#         "username": "_anujsinghal",
#         "no_of_post": 1785,
#         "no_of_followers": 681000,
#         "no_of_following": 248,
#         "name": "Anuj Singhal",
#         "type": "Digital creator",
#         "bio": "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet\u2019s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul"
#     },
#     {
#         "username": "code_flare",
#         "no_of_post": 165,
#         "no_of_followers": 216,
#         "no_of_following": 10,
#         "name": "The Journey Notebook | Travel | Food Blogger",
#         "type": "Blogger",
#         "bio": "\ud83d\udccd Exploring places & phases of life \ud83c\udf0d\n.\n\ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f\n.\n\ud83d\udcab Travel | Food | Daily life \ud83c\udf38\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#     },
#     {
#         "username": "bangalore_tech_bro",
#         "no_of_post": 402,
#         "no_of_followers": 12500,
#         "no_of_following": 890,
#         "name": "Rahul | HSR Hustler",
#         "type": "Entrepreneur",
#         "bio": "\ud83d\ude80 Building the next Unicorn in Fintech\n\u2615 3rd Wave Coffee addict\n\ud83d\udcbb Python | React | AI\n\ud83d\udccd HSR Layout, BLR\nlinktr.ee/rahulbuilds"
#     },
#     {
#         "username": "silkboard_survivor",
#         "no_of_post": 55,
#         "no_of_followers": 1200,
#         "no_of_following": 50,
#         "name": "Priya D.",
#         "type": "Public Figure",
#         "bio": "\ud83d\udea6 Stuck in traffic since 2019\n\ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs\n\ud83d\udc0d Data Scientist by day, meme maker by night\n\ud83d\udccd ORR\nbit.ly/my-traffic-rants"
#     },
#     {
#         "username": "startuphub_blr",
#         "no_of_post": 2300,
#         "no_of_followers": 45000,
#         "no_of_following": 120,
#         "name": "Startup Hub Bangalore",
#         "type": "Media",
#         "bio": "\ud83e\udd84 News from the Silicon Valley of India\n\ud83d\udce2 Funding alerts, Hiring trends, and Drama\n\ud83d\udce9 DM for features\nstartuphub.blr/newsletter"
#     },
#     {
#         "username": "foodie_in_kora",
#         "no_of_post": 890,
#         "no_of_followers": 5600,
#         "no_of_following": 400,
#         "name": "Sneha | Bangalore Eats",
#         "type": "Food & Drink",
#         "bio": "Aagrah to Truffles \ud83c\udf54\nExploring Koramangala's cafe culture \u2615\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"
#     },
#     {
#         "username": "venture_vikram",
#         "no_of_post": 120,
#         "no_of_followers": 30000,
#         "no_of_following": 500,
#         "name": "Vikram | Angel Investor",
#         "type": "Investor",
#         "bio": "\ud83d\udcb8 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n\ud83d\udccd Indiranagar\nvikram.vc/pitch-deck"
#     },
#     {
#         "username": "python_meetup_blr",
#         "no_of_post": 60,
#         "no_of_followers": 3400,
#         "no_of_following": 10,
#         "name": "PyBangalore Community",
#         "type": "Community",
#         "bio": "\ud83d\udc0d Weekly meetups for Pythonistas\n\ud83d\udccd Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore"
#     },
#     {
#         "username": "indiranagar_gossip",
#         "no_of_post": 300,
#         "no_of_followers": 8900,
#         "no_of_following": 20,
#         "name": "Indiranagar Spy",
#         "type": "Personal Blog",
#         "bio": "Not just about 100ft Road \ud83e\udd2b\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy"
#     },
#     {
#         "username": "techtrail_blr",
#         "no_of_post": 340,
#         "no_of_followers": 9100,
#         "no_of_following": 210,
#         "name": "Tech Trail Bangalore",
#         "type": "Media",
#         "bio": "\ud83d\ude80 Startup scoops & tech tales\n\ud83d\udca1 Covering Koramangala, HSR & Indiranagar\n\ud83d\udccd BLR\nlinktr.ee/techtrailblr"
#     },
#     {
#         "username": "koramangala_coder",
#         "no_of_post": 120,
#         "no_of_followers": 2800,
#         "no_of_following": 95,
#         "name": "Kora Coder",
#         "type": "Personal Blog",
#         "bio": "\ud83d\udcbb Daily coding challenges\n\u2615 Cafe-hopping + LeetCode\n\ud83d\udccd Koramangala\n[https://www.google.com/search?q=koramangala+coder](https://www.google.com/search?q=koramangala+coder)"
#     },
#     {
#         "username": "blrcowork_chronicles",
#         "no_of_post": 480,
#         "no_of_followers": 6700,
#         "no_of_following": 180,
#         "name": "Cowork Chronicles BLR",
#         "type": "Community",
#         "bio": "\ud83c\udfe2 Exploring coworking spaces\n\ud83d\udc68\u200d\ud83d\udcbb For freelancers & founders\n\ud83d\udccd Bellandur\nbit.ly/cowork-chronicles"
#     },
#     {
#         "username": "devhub_koramangala",
#         "no_of_post": 210,
#         "no_of_followers": 4500,
#         "no_of_following": 60,
#         "name": "DevHub Koramangala",
#         "type": "Community",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Nightly coding jams\n\ud83d\udcda React | Python | AI\n\ud83d\udccd Koramangala 5th Block\n[https://www.google.com/search?q=devhub+koramangala](https://www.google.com/search?q=devhub+koramangala)"
#     },
#     {
#         "username": "ai_bengaluru",
#         "no_of_post": 150,
#         "no_of_followers": 15200,
#         "no_of_following": 140,
#         "name": "AI Bengaluru",
#         "type": "Tech",
#         "bio": "\ud83e\udd16 AI trends, events & demos\n\ud83d\udccd BLR\nai-blr.tech"
#     },
#     {
#         "username": "frontend_blr",
#         "no_of_post": 95,
#         "no_of_followers": 3900,
#         "no_of_following": 30,
#         "name": "Frontend BLR",
#         "type": "Community",
#         "bio": "\ud83c\udfa8 UI/UX | Web Dev | Tailwind\n\ud83d\udccd Indiranagar\n[https://www.google.com/search?q=frontendblr](https://www.google.com/search?q=frontendblr)"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_post": 600,
#         "no_of_followers": 22000,
#         "no_of_following": 300,
#         "name": "HSR Startup Stories",
#         "type": "Media",
#         "bio": "\ud83e\udd84 Founder journeys from HSR\n\ud83d\udccd BLR\nhsrstartups.in"
#     },
#     {
#         "username": "python_wallah_blr",
#         "no_of_post": 80,
#         "no_of_followers": 1700,
#         "no_of_following": 40,
#         "name": "Python Wallah BLR",
#         "type": "Educator",
#         "bio": "\ud83d\udc0d Python tips daily\n\ud83d\udccd BTM Layout\npythonwallah.in"
#     },
#     {
#         "username": "btm_dev_cafe",
#         "no_of_post": 140,
#         "no_of_followers": 2200,
#         "no_of_following": 120,
#         "name": "Dev Caf\u00e9 BTM",
#         "type": "Community",
#         "bio": "\u2615 Coffee + Code sessions\n\ud83d\udccd BTM Layout\nlinktr.ee/btmdevcafe"
#     },
#     {
#         "username": "blrautomation_club",
#         "no_of_post": 90,
#         "no_of_followers": 5800,
#         "no_of_following": 65,
#         "name": "Automation Club BLR",
#         "type": "Community",
#         "bio": "\ud83d\udee0\ufe0f RPA | Python Scripts | AI\n\ud83d\udccd KR Puram\n[https://www.google.com/search?q=blrautomationclub](https://www.google.com/search?q=blrautomationclub)"
#     },
#     {
#         "username": "coding_koramangala",
#         "no_of_post": 70,
#         "no_of_followers": 1350,
#         "no_of_following": 15,
#         "name": "Coding Koramangala",
#         "type": "Community",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Weekly coding walks\n\ud83d\udccd Koramangala\nbit.ly/coding-kormangala"
#     },
#     {
#         "username": "devlife_bangalore",
#         "no_of_post": 430,
#         "no_of_followers": 18000,
#         "no_of_following": 450,
#         "name": "DevLife Bangalore",
#         "type": "Blog",
#         "bio": "\ud83d\udcbc Life of BLR developers\n\u2615 Cafes, layoffs & chai\ndevlifeblr.medium.com"
#     },
#     {
#         "username": "cloud_blr",
#         "no_of_post": 160,
#         "no_of_followers": 9400,
#         "no_of_following": 210,
#         "name": "Cloud BLR",
#         "type": "Tech",
#         "bio": "\u2601\ufe0f Cloud + DevOps content\n\ud83d\udccd Electronic City\ncloudblr.dev"
#     },
#     {
#         "username": "electroniccity_coder",
#         "no_of_post": 100,
#         "no_of_followers": 3100,
#         "no_of_following": 55,
#         "name": "ECity Coder",
#         "type": "Personal Blog",
#         "bio": "\ud83d\udcbb Python backend dev\n\ud83d\udccd E-city Phase 1\n[https://www.google.com/search?q=ecity+coder](https://www.google.com/search?q=ecity+coder)"
#     },
#     {
#         "username": "bangalore_datascience_club",
#         "no_of_post": 240,
#         "no_of_followers": 12700,
#         "no_of_following": 110,
#         "name": "BLR Data Science Club",
#         "type": "Community",
#         "bio": "\ud83d\udcca ML sessions + Kaggle nights\n\ud83d\udccd MG Road WeWork\ndatascienceblr.club"
#     },
#     {
#         "username": "blrmobiledevs",
#         "no_of_post": 130,
#         "no_of_followers": 4200,
#         "no_of_following": 80,
#         "name": "BLR Mobile Devs",
#         "type": "Community",
#         "bio": "\ud83d\udcf1 Flutter | React Native\n\ud83d\udccd Indiranagar\n[https://www.google.com/search?q=blrmobiledevs](https://www.google.com/search?q=blrmobiledevs)"
#     },
#     {
#         "username": "react_bangalore",
#         "no_of_post": 300,
#         "no_of_followers": 14000,
#         "no_of_following": 200,
#         "name": "React Bangalore",
#         "type": "Community",
#         "bio": "\u269b\ufe0f React meetups & workshops\n\ud83d\udccd BLR\nreactblr.dev"
#     },
#     {
#         "username": "devs_of_whitefield",
#         "no_of_post": 190,
#         "no_of_followers": 6600,
#         "no_of_following": 150,
#         "name": "Whitefield Devs",
#         "type": "Community",
#         "bio": "\ud83d\udcbb Tech + productivity\n\ud83d\udccd Whitefield\nwhitefielddevs.in"
#     },
#     {
#         "username": "indiranagar_debugger",
#         "no_of_post": 75,
#         "no_of_followers": 2000,
#         "no_of_following": 30,
#         "name": "Indiranagar Debugger",
#         "type": "Blog",
#         "bio": "\ud83d\udc1e Debugging life & code\n\ud83d\udccd Indiranagar\nbit.ly/indiranagar-debugger"
#     },
#     {
#         "username": "koramangala_ai_meet",
#         "no_of_post": 85,
#         "no_of_followers": 7400,
#         "no_of_following": 22,
#         "name": "Kora AI Meet",
#         "type": "Community",
#         "bio": "\ud83e\udd16 AI jam sessions\n\ud83d\udccd Koramangala 1st Block\nkora-ai.club"
#     },
#     {
#         "username": "blrit_guy",
#         "no_of_post": 230,
#         "no_of_followers": 5300,
#         "no_of_following": 200,
#         "name": "BLR IT Guy",
#         "type": "Public Figure",
#         "bio": "\ud83d\udcbc Big Tech employee life\n\ud83d\udccd Manyata Tech Park\n[https://www.google.com/search?q=blr+it+guy](https://www.google.com/search?q=blr+it+guy)"
#     },
#     {
#         "username": "startup_grind_bangalore",
#         "no_of_post": 1100,
#         "no_of_followers": 38000,
#         "no_of_following": 420,
#         "name": "Startup Grind Bangalore",
#         "type": "Community",
#         "bio": "\ud83d\udd25 Founder wisdom + events\n\ud83d\udccd BLR\nstartupgrind.com/bangalore"
#     },
#     {
#         "username": "coding_in_indiranagar",
#         "no_of_post": 60,
#         "no_of_followers": 1100,
#         "no_of_following": 25,
#         "name": "Coding in Indiranagar",
#         "type": "Personal Blog",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Python & JS notes\n\ud83d\udccd 100ft Road\nbit.ly/coding-indiranagar"
#     },
#     {
#         "username": "devwalk_blr",
#         "no_of_post": 50,
#         "no_of_followers": 900,
#         "no_of_following": 15,
#         "name": "Dev Walk BLR",
#         "type": "Community",
#         "bio": "\ud83d\udeb6\u200d\u2642\ufe0f Walk + talk tech\n\ud83d\udccd Lalbagh\ndevwalk.in"
#     },
#     {
#         "username": "bellandur_bug_hunter",
#         "no_of_post": 110,
#         "no_of_followers": 3900,
#         "no_of_following": 75,
#         "name": "Bellandur Bug Hunter",
#         "type": "Blog",
#         "bio": "\ud83d\udc1b QA life in BLR\n\ud83d\udccd Bellandur\ntinyurl.com/bughunterblr"
#     },
#     {
#         "username": "blrcoders_space",
#         "no_of_post": 340,
#         "no_of_followers": 25000,
#         "no_of_following": 300,
#         "name": "BLR Coders Space",
#         "type": "Community",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Coding news, memes\n\ud83d\udccd BLR\nblrcoders.space"
#     },
#     {
#         "username": "nextjs_blr",
#         "no_of_post": 45,
#         "no_of_followers": 2300,
#         "no_of_following": 40,
#         "name": "Next.js Bangalore",
#         "type": "Community",
#         "bio": "\u26a1 Modern web dev meetups\n\ud83d\udccd MG Road\nnextjsblr.dev"
#     },
#     {
#         "username": "techpark_musings",
#         "no_of_post": 130,
#         "no_of_followers": 6000,
#         "no_of_following": 100,
#         "name": "Tech Park Musings",
#         "type": "Blog",
#         "bio": "\ud83c\udfe2 Manyata | EcoSpace | Bagmane\n\ud83d\udccd Bangalore\nmedium.com/@techparkmusings"
#     },
#     {
#         "username": "koramangala_freelancers",
#         "no_of_post": 200,
#         "no_of_followers": 4000,
#         "no_of_following": 70,
#         "name": "Koramangala Freelancers",
#         "type": "Community",
#         "bio": "\ud83d\udcbb Remote work + gigs\n\ud83d\udccd Koramangala\nkorafreelancers.co"
#     },
#     {
#         "username": "blronlinejobs",
#         "no_of_post": 560,
#         "no_of_followers": 21000,
#         "no_of_following": 190,
#         "name": "BLR Online Jobs",
#         "type": "Media",
#         "bio": "\ud83d\udcbc Hiring in tech daily\n\ud83d\udccd BLR\nblronlinejobs.in"
#     },
#     {
#         "username": "datascience_daily_blr",
#         "no_of_post": 150,
#         "no_of_followers": 8800,
#         "no_of_following": 140,
#         "name": "DS Daily BLR",
#         "type": "Education",
#         "bio": "\ud83d\udcca ML tricks & resources\n\ud83d\udccd BLR\ndsdailyblr.com"
#     },
#     {
#         "username": "python_koramangala",
#         "no_of_post": 42,
#         "no_of_followers": 850,
#         "no_of_following": 12,
#         "name": "Python Koramangala",
#         "type": "Community",
#         "bio": "\ud83d\udc0d Weekly Python tasks\n\ud83d\udccd Koramangala\nbit.ly/python-kora"
#     },
#     {
#         "username": "coding_chai_bangalore",
#         "no_of_post": 280,
#         "no_of_followers": 10000,
#         "no_of_following": 230,
#         "name": "Coding Chai",
#         "type": "Blog",
#         "bio": "\u2615 Code + chai\n\ud83d\udccd JP Nagar\ncodingchai.in"
#     },
#     {
#         "username": "blrgitcommunity",
#         "no_of_post": 75,
#         "no_of_followers": 3200,
#         "no_of_following": 20,
#         "name": "Git Community BLR",
#         "type": "Tech",
#         "bio": "\ud83d\udd27 Git tips & collab sessions\n\ud83d\udccd BLR\ngitblr.dev"
#     },
#     {
#         "username": "indiranagar_startups",
#         "no_of_post": 320,
#         "no_of_followers": 12500,
#         "no_of_following": 100,
#         "name": "Indiranagar Startups",
#         "type": "Media",
#         "bio": "\ud83e\udd84 Spotlight on early-stage founders\n\ud83d\udccd Indiranagar\nindiranagarstartups.in"
#     },
#     {
#         "username": "machinelearning_blr",
#         "no_of_post": 210,
#         "no_of_followers": 19000,
#         "no_of_following": 250,
#         "name": "Machine Learning BLR",
#         "type": "Tech",
#         "bio": "\ud83e\udd16 ML articles & demos\n\ud83d\udccd BLR\nmlblr.tech"
#     },
#     {
#         "username": "koramangala_script_kiddie",
#         "no_of_post": 55,
#         "no_of_followers": 1050,
#         "no_of_following": 18,
#         "name": "Script Kiddie Kora",
#         "type": "Personal Blog",
#         "bio": "\ud83d\udcbb Learning Python & JS\n\ud83d\udccd Koramangala\n[https://www.google.com/search?q=script+kiddie+kora](https://www.google.com/search?q=script+kiddie+kora)"
#     },
#     {
#         "username": "hsr_dev_buddy",
#         "no_of_post": 120,
#         "no_of_followers": 2700,
#         "no_of_following": 40,
#         "name": "HSR Dev Buddy",
#         "type": "Community",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Peer learning club\n\ud83d\udccd HSR Layout\nhsrdevbuddy.in"
#     },
#     {
#         "username": "blrcloudhackers",
#         "no_of_post": 140,
#         "no_of_followers": 7900,
#         "no_of_following": 200,
#         "name": "BLR Cloud Hackers",
#         "type": "Tech",
#         "bio": "\u2601\ufe0f AWS | Azure | GCP\n\ud83d\udccd BLR\ncloudhackers.in"
#     },
#     {
#         "username": "techwriter_blr",
#         "no_of_post": 60,
#         "no_of_followers": 1900,
#         "no_of_following": 50,
#         "name": "BLR Tech Writer",
#         "type": "Writer",
#         "bio": "\ud83d\udcdd Tech explainers\n\ud83d\udccd Bangalore\nmedium.com/@blrtechwriter"
#     },
#     {
#         "username": "dev_canteen_koramangala",
#         "no_of_post": 180,
#         "no_of_followers": 5400,
#         "no_of_following": 120,
#         "name": "Dev Canteen",
#         "type": "Community",
#         "bio": "\ud83c\udf54 Food + code meetups\n\ud83d\udccd Koramangala\ndevcanteen.in"
#     },
#     {
#         "username": "pythonlady_blr",
#         "no_of_post": 70,
#         "no_of_followers": 4200,
#         "no_of_following": 35,
#         "name": "Python Lady BLR",
#         "type": "Educator",
#         "bio": "\ud83d\udc0d Python + data tutorials\n\ud83d\udccd Indiranagar\npythonlady.in"
#     },
#     {
#         "username": "bangalore_oss",
#         "no_of_post": 250,
#         "no_of_followers": 9800,
#         "no_of_following": 90,
#         "name": "Bangalore Open Source",
#         "type": "Community",
#         "bio": "\ud83d\udee0\ufe0f OSS projects & contributions\n\ud83d\udccd BLR\nossblr.dev"
#     },
#     {
#         "username": "blr_ai_founders",
#         "no_of_post": 85,
#         "no_of_followers": 6600,
#         "no_of_following": 70,
#         "name": "BLR AI Founders",
#         "type": "Entrepreneur",
#         "bio": "\ud83e\udd16 AI startup builders\n\ud83d\udccd Indiranagar\naifoundersblr.com"
#     },
#     {
#         "username": "coders_of_bangalore",
#         "no_of_post": 300,
#         "no_of_followers": 17000,
#         "no_of_following": 280,
#         "name": "Coders of Bangalore",
#         "type": "Community",
#         "bio": "\ud83d\udc68\u200d\ud83d\udcbb Showcasing BLR devs\n\ud83d\udccd BLR\ncodersofbangalore.in"
#     },
#     {
#         "username": "dailydev_bangalore",
#         "no_of_post": 180,
#         "no_of_followers": 12200,
#         "no_of_following": 200,
#         "name": "Daily Dev Bangalore",
#         "type": "Tech",
#         "bio": "\ud83d\udcdd Tips | Tools | Tutorials\n\ud83d\udccd BLR\ndailydevblr.co"
#     },
#     {
#         "username": "bangalore_backend",
#         "no_of_post": 90,
#         "no_of_followers": 4800,
#         "no_of_following": 60,
#         "name": "BLR Backend Devs",
#         "type": "Tech",
#         "bio": "\ud83d\udd27 Python | Go | Node\n\ud83d\udccd BLR\nbackendblr.tech"
#     },
#     {
#         "username": "ecity_techies",
#         "no_of_post": 140,
#         "no_of_followers": 3900,
#         "no_of_following": 55,
#         "name": "E-city Techies",
#         "type": "Community",
#         "bio": "\ud83d\udcbc Tech park life\n\ud83d\udccd Electronic City\necitytechies.in"
#     },
#     {
#         "username": "fullstack_blr_club",
#         "no_of_post": 110,
#         "no_of_followers": 7200,
#         "no_of_following": 85,
#         "name": "Fullstack BLR Club",
#         "type": "Community",
#         "bio": "\ud83d\udcbb MERN | Python | DevOps\n\ud83d\udccd JP Nagar\nfullstackblr.club"
#     },
#     {
#         "username": "coding_runners_blr",
#         "no_of_post": 100,
#         "no_of_followers": 2500,
#         "no_of_following": 35,
#         "name": "Coding Runners",
#         "type": "Community",
#         "bio": "\ud83c\udfc3\u200d\u2642\ufe0f Running + coding\n\ud83d\udccd Cubbon Park\ncodingrunners.in"
#     },
#     {
#         "username": "bangalore_engineers_diary",
#         "no_of_post": 270,
#         "no_of_followers": 8500,
#         "no_of_following": 120,
#         "name": "Engineers Diary BLR",
#         "type": "Blog",
#         "bio": "\ud83d\udcd8 Life & tech rants\n\ud83d\udccd BLR\nmedium.com/@engineersdiaryblr"
#     }
# ]

# %% [markdown]
# # Who has Max Posts

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['no_of_post']):
        max=chunk['no_of_post']
        chunk_with_max_post=chunk
print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_post': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# # Who has Max Followers

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['no_of_followers']):
        max=chunk['no_of_followers']
        chunk_with_max_followers=chunk
print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'no_of_post': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# # Who has Max Following

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['no_of_following']):
        max=chunk['no_of_following']
        chunk_with_max_following=chunk
print(chunk_with_max_following)
# Out:
# {'username': 'bangalore_tech_bro', 'no_of_post': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'name': 'Rahul | HSR Hustler', 'type': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# # Categories

# %%
categories=set()
for chunk in all_chunks:
    categories.add(chunk['type'])
print(categories,len(categories))
# Out:
# {'Tech Creator', 'Backend Developer', 'Frontend Dev', 'Digital creator', 'Design', 'Food & Drink', 'Software Engineer', 'Tech', 'Cafe Nerd', 'Data Science', 'Lifestyle', 'Founder', 'Engineer', 'Cafe Explorer', 'Artist + Coder', 'Coder', 'Nonprofit organization', 'Blogger', 'Personal Blog', 'Public Figure', 'Blog', 'Community', 'Media', 'Product Manager', 'Entrepreneur', 'Investor', 'Full-stack Dev', 'Data Scientist', 'Developer', 'Writer', 'Recruiter', 'Education', 'Comedy', 'Educator'} 34
